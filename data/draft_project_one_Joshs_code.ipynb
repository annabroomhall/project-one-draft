# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import json as json

# File to Load (Remember to Change These)
crime_2018 = "../Resources/2018-19-data_sa_crime.csv"
crime_2019 = "../Resources/2019-20-fullyr-data_sa_crime (1).csv"
crime_2020 = "../Resources/2020-21_crime_qtr1_and_qtr2 (1).csv"
sa_postcodes = "../Resources/australian_postcodes (1).csv"

# Read data files and store into DataFrames
crime_2018_df = pd.read_csv(crime_2018)
crime_2019_df = pd.read_csv(crime_2019)
crime_2020_df = pd.read_csv(crime_2020)
sa_postcodes_df = pd.read_csv(sa_postcodes)

# %%
#merging 4 crime datasets into a merged_data dataframe
merged_data = pd.concat([crime_2018_df,crime_2019_df,crime_2020_df], ignore_index=True)

# %%
#cleaning merged_data dataframe and removing rows containing null values
clean_crime_data = merged_data.dropna(how='any')

# %%
#renaming SA postcode set to allow merge on shared column
sa_postcodes_df = sa_postcodes_df.rename(columns = {"postcode":"Postcode - Incident",
                                                   'locality': "Suburb - Incident"})

# %%
#using loc function to remove any crimes listed against postcode "NOT DISCLOSED"
clean_crime_data = clean_crime_data.loc[clean_crime_data["Postcode - Incident"]!= "NOT DISCLOSED"].copy()

# %%
#changing datatype from object to integer to allow merge of two datasets
clean_crime_data["Postcode - Incident"] = clean_crime_data["Postcode - Incident"].astype(str).astype(int)

# %%
#Check datatypes of clean_crime_data
#clean_crime_data.dtypes

# %%
#Check datatypes of sa_postcodes_df
#sa_postcodes_df.dtypes

# %%
#merge both datasets - using left join to drop any postcode data not associated with crimes in SA
crime_postcode_merge_df = pd.merge(clean_crime_data, sa_postcodes_df, on = ["Postcode - Incident", "Suburb - Incident"], how = "left")

# %%
#review updated dataframe
crime_postcode_merge_df
# Out:
#        Reported Date Suburb - Incident  Postcode - Incident  \
# 0          1/07/2018    ABERFOYLE PARK                 5159
# 1          1/07/2018          ADELAIDE                 5000
# 2          1/07/2018          ADELAIDE                 5000
# 3          1/07/2018          ADELAIDE                 5000
# 4          1/07/2018          ADELAIDE                 5000
# ...              ...               ...                  ...
# 227842    31/12/2020         WOODCROFT                 5162
# 227843    31/12/2020         WOODVILLE                 5011
# 227844    31/12/2020         WOODVILLE                 5011
# 227845    31/12/2020   WOODVILLE SOUTH                 5011
# 227846    31/12/2020    WOODVILLE WEST                 5011
#
#         Offence Level 1 Description        Offence Level 2 Description  \
# 0         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 1         OFFENCES AGAINST PROPERTY  PROPERTY DAMAGE AND ENVIRONMENTAL
# 2         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 3         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 4         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# ...                             ...                                ...
# 227842  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 227843    OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 227844  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 227845    OFFENCES AGAINST PROPERTY  PROPERTY DAMAGE AND ENVIRONMENTAL
# 227846    OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
#
#                     Offence Level 3 Description  Offence count       id state  \
# 0                      Theft from motor vehicle            1.0  15577.0    SA
# 1       Other property damage and environmental            1.0  13683.0    SA
# 2                                   Other theft            5.0  13683.0    SA
# 3           Receive or handle proceeds of crime            1.0  13683.0    SA
# 4                      Theft from motor vehicle            1.0  13683.0    SA
# ...                                         ...            ...      ...   ...
# 227842  Serious Assault not resulting in injury            1.0  15588.0    SA
# 227843                          Theft from shop            1.0  13718.0    SA
# 227844  Serious Assault not resulting in injury            1.0  13718.0    SA
# 227845  Other property damage and environmental            1.0  13720.0    SA
# 227846                          Theft from shop            1.0  13721.0    SA
#
#               long  ...  SA2_MAINCODE_2016         SA2_NAME_2016  \
# 0       138.603897  ...        403041071.0        Aberfoyle Park
# 1       138.608637  ...        401011001.0              Adelaide
# 2       138.608637  ...        401011001.0              Adelaide
# 3       138.608637  ...        401011001.0              Adelaide
# 4       138.608637  ...        401011001.0              Adelaide
# ...            ...  ...                ...                   ...
# 227842  138.565224  ...        403041084.0  Morphett Vale - East
# 227843  138.527677  ...        404011090.0              Beverley
# 227844  138.527677  ...        404011090.0              Beverley
# 227845  138.527677  ...        404011090.0              Beverley
# 227846  138.527677  ...        404011090.0              Beverley
#
#        SA3_CODE_2016  SA3_NAME_2016  SA4_CODE_2016  \
# 0            40304.0    Onkaparinga          403.0
# 1            40101.0  Adelaide City          401.0
# 2            40101.0  Adelaide City          401.0
# 3            40101.0  Adelaide City          401.0
# 4            40101.0  Adelaide City          401.0
# ...              ...            ...            ...
# 227842       40304.0    Onkaparinga          403.0
# 227843       40401.0  Charles Sturt          404.0
# 227844       40401.0  Charles Sturt          404.0
# 227845       40401.0  Charles Sturt          404.0
# 227846       40401.0  Charles Sturt          404.0
#
#                        SA4_NAME_2016  RA_2011 RA_2016 MMM_2015  MMM_2019
# 0                   Adelaide - South      1.0     1.0      1.0       1.0
# 1       Adelaide - Central and Hills      1.0     1.0      1.0       1.0
# 2       Adelaide - Central and Hills      1.0     1.0      1.0       1.0
# 3       Adelaide - Central and Hills      1.0     1.0      1.0       1.0
# 4       Adelaide - Central and Hills      1.0     1.0      1.0       1.0
# ...                              ...      ...     ...      ...       ...
# 227842              Adelaide - South      1.0     1.0      1.0       1.0
# 227843               Adelaide - West      1.0     1.0      1.0       1.0
# 227844               Adelaide - West      1.0     1.0      1.0       1.0
# 227845               Adelaide - West      1.0     1.0      1.0       1.0
# 227846               Adelaide - West      1.0     1.0      1.0       1.0
#
# [227847 rows x 33 columns]

# %%
crime_postcode_merge_df = crime_postcode_merge_df.drop(columns=['SA2_MAINCODE_2016', 'type', 'sa3', 'SA3_CODE_2016', 
                                      'SA1_MAINCODE_2011', 'id', 'SA1_MAINCODE_2016',
                                      'SA4_CODE_2016','RA_2011','RA_2016','MMM_2015','MMM_2019',
                                      'status','sa4','state'])

# %%
crime_postcode_merge_df
# Out:
#        Reported Date Suburb - Incident  Postcode - Incident  \
# 0          1/07/2018    ABERFOYLE PARK                 5159
# 1          1/07/2018          ADELAIDE                 5000
# 2          1/07/2018          ADELAIDE                 5000
# 3          1/07/2018          ADELAIDE                 5000
# 4          1/07/2018          ADELAIDE                 5000
# ...              ...               ...                  ...
# 227842    31/12/2020         WOODCROFT                 5162
# 227843    31/12/2020         WOODVILLE                 5011
# 227844    31/12/2020         WOODVILLE                 5011
# 227845    31/12/2020   WOODVILLE SOUTH                 5011
# 227846    31/12/2020    WOODVILLE WEST                 5011
#
#         Offence Level 1 Description        Offence Level 2 Description  \
# 0         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 1         OFFENCES AGAINST PROPERTY  PROPERTY DAMAGE AND ENVIRONMENTAL
# 2         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 3         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 4         OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# ...                             ...                                ...
# 227842  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 227843    OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
# 227844  OFFENCES AGAINST THE PERSON      ACTS INTENDED TO CAUSE INJURY
# 227845    OFFENCES AGAINST PROPERTY  PROPERTY DAMAGE AND ENVIRONMENTAL
# 227846    OFFENCES AGAINST PROPERTY         THEFT AND RELATED OFFENCES
#
#                     Offence Level 3 Description  Offence count        long  \
# 0                      Theft from motor vehicle            1.0  138.603897
# 1       Other property damage and environmental            1.0  138.608637
# 2                                   Other theft            5.0  138.608637
# 3           Receive or handle proceeds of crime            1.0  138.608637
# 4                      Theft from motor vehicle            1.0  138.608637
# ...                                         ...            ...         ...
# 227842  Serious Assault not resulting in injury            1.0  138.565224
# 227843                          Theft from shop            1.0  138.527677
# 227844  Serious Assault not resulting in injury            1.0  138.527677
# 227845  Other property damage and environmental            1.0  138.527677
# 227846                          Theft from shop            1.0  138.527677
#
#               lat                              dc        sa3name  \
# 0      -35.061705                SOMERTON PARK DC    Onkaparinga
# 1      -34.937459  ADELAIDE CITY DELVRY C & BOXES  Adelaide City
# 2      -34.937459  ADELAIDE CITY DELVRY C & BOXES  Adelaide City
# 3      -34.937459  ADELAIDE CITY DELVRY C & BOXES  Adelaide City
# 4      -34.937459  ADELAIDE CITY DELVRY C & BOXES  Adelaide City
# ...           ...                             ...            ...
# 227842 -35.112119                     LONSDALE DC    Onkaparinga
# 227843 -34.883282                 REGENCY PARK DC  Charles Sturt
# 227844 -34.883282                 REGENCY PARK DC  Charles Sturt
# 227845 -34.883282                 REGENCY PARK DC  Charles Sturt
# 227846 -34.883282                 REGENCY PARK DC  Charles Sturt
#
#                              sa4name region  Lat_precise  Long_precise  \
# 0                   Adelaide - South     R2   -35.067000    138.600000
# 1       Adelaide - Central and Hills     R2   -34.932829    138.603813
# 2       Adelaide - Central and Hills     R2   -34.932829    138.603813
# 3       Adelaide - Central and Hills     R2   -34.932829    138.603813
# 4       Adelaide - Central and Hills     R2   -34.932829    138.603813
# ...                              ...    ...          ...           ...
# 227842              Adelaide - South     R2   -35.118261    138.543736
# 227843               Adelaide - West     R2   -34.881000    138.535000
# 227844               Adelaide - West     R2   -34.881000    138.535000
# 227845               Adelaide - West     R2   -34.881000    138.535000
# 227846               Adelaide - West     R2   -34.882800    138.525800
#
#                SA2_NAME_2016  SA3_NAME_2016                 SA4_NAME_2016
# 0             Aberfoyle Park    Onkaparinga              Adelaide - South
# 1                   Adelaide  Adelaide City  Adelaide - Central and Hills
# 2                   Adelaide  Adelaide City  Adelaide - Central and Hills
# 3                   Adelaide  Adelaide City  Adelaide - Central and Hills
# 4                   Adelaide  Adelaide City  Adelaide - Central and Hills
# ...                      ...            ...                           ...
# 227842  Morphett Vale - East    Onkaparinga              Adelaide - South
# 227843              Beverley  Charles Sturt               Adelaide - West
# 227844              Beverley  Charles Sturt               Adelaide - West
# 227845              Beverley  Charles Sturt               Adelaide - West
# 227846              Beverley  Charles Sturt               Adelaide - West
#
# [227847 rows x 18 columns]
